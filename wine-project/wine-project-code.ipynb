# %% [markdown]
# # About DataSet winedataset.csv

# %% [raw]
# The dataset contains 178 rows and 14 features for which details are given below:
#     1. Class: denotes quality of wine (1 or 2 or 3)
#     2. Alcohol: deonotes content of alcohol in wine
#     3. Malic acid: denotes content of malic acid in wine
#     4. Ash: denotes content of ash in wine.
#     5. Alcalinity of ash: denotes alcalinity of ash in wine
#     6. Magnesium: content of magnesium in wine
#     7. Total phenols: content of phenols in wine
#     8. Flavanoids: content of flavanoids in wine
#     9. Nonflavanoid phenols: content of nonflavanoid phenols in wine
#     10. Proanthocyanins: content of proanthocyanins in wine
#     11. Color intensity: color intensity of wine
#     12. Hue: hue of wine
#     13. diluted wines: how much wine is diluted
#     14. Proline: content of proline in wine
# Since, quality of wine ie. Class is our target findings, so, it is a classification problem.

# %% [markdown]
# # Loading Dataset

# %%
import pandas as pd
df = pd.read_csv('winedataset.csv')
df.head() #printing first 5 rows
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92         1065
# 1             4.38  1.05           3.40         1050
# ...

# %%
#Checking Dimension of dataset
df.shape
# Out:
# (178, 14)

# %%
#Checking Summary of DataSet
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [raw]
# Remarks:
#     -count for all the features are same, so no data is missing.
#     -mean and median for all the features are almost same, so lesser or nill skewness will be there.
#     -difference between 75th percentile and max is higher in Color intensity and Proline, therefore, outliers may be present.

# %% [markdown]
# # Preparing Data

# %%
#Checking data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %% [raw]
# Remarks:
#     -No object or string type data is present, so, encoding is not required.

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
#Display null values with the help of heatmap
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.isnull())
plt.show()

# %% [raw]
# Remarks:
#     -No null values present.

# %%
#copying dataset for further EDA
df_new = df.copy()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Univariate Analysis

# %%
#Checking Class with count plot
sns.countplot(data=df_new, x='Class')
plt.title('Count Plot for Class feature')
plt.show()

# %% [raw]
# Remarks:
#     -There are three Class of wine is present in dataset.
#     -Most of wine are with Class 2.

# %%
#Checking Alcohol with distplot
sns.distplot(df_new["Alcohol"])
plt.title('Distrubution Plot For Alcohol')
plt.show()

# %% [raw]
# Remarks:
#     -Distribution plot show data is distributed normally but it is not in well shape.

# %%
#Similerly Checking all other features with distribution plot
features = df_new.iloc[:,2:].columns
print(features)
print(len(features))
# Out:
# Index(['Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols',
#        'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins',
#        'Color intensity', 'Hue', 'diluted wines', 'Proline    '],
#       dtype='object')
# 12

# %%
rows=3
cols=4
fig, axes = plt.subplots(rows,cols,figsize=(16,20))
k=0

for i in range(rows):
    for j in range(cols):
        sns.distplot(df_new[features[k]],ax=axes[i][j])
        axes[i][j].set_title(f'Distribution Plot For {features[k]}',fontsize=10)
        k += 1
            
plt.show()

# %% [raw]
# Remarks:
#     -Malic acid, Total phenols, Flavanoids and diluted wines shows presence of skewness in data.

# %%
#Checking all the features with Box-Plot
features = df_new.iloc[:,1:].columns
print(features)
print(len(features))
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')
# 13

# %%
rows = 4
cols = 4
fig, axes = plt.subplots(rows,cols,figsize=(16,20))
k=0
color = ['r','g','b','y','m','c','coral','skyblue','indigo','lightgreen','yellowgreen','olive','gold','firebrick']
for i in range(rows):
    for j in range(cols):
        sns.boxplot(df_new[features[k]],ax=axes[i][j], orient='v',color=color[k])
        axes[i][j].set_title(f'Box-Plot for [{features[k]}]')
        k += 1
        if k == len(features):
            break
            
plt.show()

# %% [raw]
# Remarks:
#     -Malic acid, Ash, Alcalinity of ash, Magnesium, Proanthocyanins, Color intensity and Hue have some or more outliers.

# %% [markdown]
# # BiVariate Analysis

# %%
#Checking Relationship between Alcohol and Class using Scatter Plot
sns.scatterplot(x='Alcohol',y='Class',data=df_new)
plt.title('Alcohol vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wines are present with Alcohol 12.8 to 14.4
#     -Most of the Class 2 wines are present with Alcohol 11.5 to 12.8
#     -Most of the Class 3 wines are present with Alcohol 12.2 to 14

# %%
#Checking Relationship between Malic acid and Class using Scatter Plot
sns.scatterplot(x='Malic acid',y='Class',data=df_new)
plt.title('Malic acid vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with 1.2 to 2.2 Malic acid.
#     -Most of the Class 2 wine is present with 0.8 to 2.2 Malic acid.
#     -Most of the Class 3 wine is present with 2.3 to 4.

# %%
#Checking Relationship between Ash and Class with the help of Scatter Plot
sns.scatterplot(x='Ash',y='Class',data=df_new)
plt.title('Ash vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with 2.1 to 2.7
#     -Most of the Class 2 wine is present with 1.85 to 2.75
#     -Most of the Class 3 wine is present with 2.15 to 2.8

# %%
#Checking Relationship between Alcalinity of ash and Class with Scatter Plot
sns.scatterplot(x='Alcalinity of ash',y='Class',data=df_new)
plt.title('Alcalinity of ash vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with Alcalinity of ash 14.5 to 21.
#     -Most of the Class 2 wine is present with Alcalinity of ash 16.5 to 25.
#     -Most of the Class 3 wine is present with Alcalinity of ash 17 to 26.

# %%
#Checking Relationship between Magnesium and Class using Scatter Plot
sns.scatterplot(x='Magnesium',y='Class',data=df_new)
plt.title('Magnesium vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with Magnesium 88 to 125
#     -Most of the Class 2 wine is present with Magnesium 80 to 105
#     -Most of the Class 3 wine is present with Magnesium 85 to 110

# %%
#Checking relationship between Total phenols and Class using Scatter Plot
sns.scatterplot(x='Total phenols',y='Class',data=df_new)
plt.title('Total phenols vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with Total phenols 2.4 to 3.4
#     -Most of the Class 2 wine is present with Total phenols 1.6 to 3.0
#     -Most of the Class 3 wine is present with Total phenols 1.2 to 2.1

# %%
#Checking relationship between Flavanoids and Class with Scatter Plot
sns.scatterplot(x='Flavanoids',y='Class',data=df_new)
plt.title('Flavanoids vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is having Flavanoids 2.2 to 3.9
#     -Most of the Class 2 wine is having Flavanoids 1.2 to 3.2
#     -Most of the Class 3 wine is having Flavanoids 0.3 to 1.5

# %%
#Checking relationship between Nonflavanoid phenols and Class using Scatter Plot
sns.scatterplot(x='Nonflavanoid phenols', y='Class',data=df_new)
plt.title('Nonflavanoid phenols vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of Class 1 wine is present with Nonflavanoid phenols 0.2 to 0.35
#     -Most of Class 2 wine is present with Nonflavanoid phenols 0.21 to 0.6
#     -Most of Class 3 wine is present with Nonflavanoid phenols 0.4 to 0.6

# %%
#Checking relationship between Proanthocyanins and Class using scatter plot
sns.scatterplot(x='Proanthocyanins',y='Class',data=df_new)
plt.title('Proanthocyanins vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with Proanthocyanins 1.24 to 2.5
#     -Most of the Class 2 wine is present with Proanthocyanins 1.0 to 2.1
#     -Most of the Class 3 wine is present with Proanthocyanins 0.6 to 1.6

# %%
#Checking relationship between Color intensity and Class using Scatter plot
sns.scatterplot(x='Color intensity',y='Class',data=df_new)
plt.title('Color intensity vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with 3.5 to 7.9 Color intensity
#     -Most of the Class 2 wine is present with 2 to 4 Color intensity
#     -Most of the Class 3 wine is present with 4 to 11 Color intensity

# %%
#Checking relationship between Hue and Class using Scatter Plot
sns.scatterplot(x='Hue',y='Class',data=df_new)
plt.title('Hue vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with Hue 0.84 to 1.3
#     -Most of the Class 2 wine is present with Hue 0.68 to 1.45
#     -Most of the Class 3 wine is present with Hue 0.58 to 0.9

# %%
#Checking relationship between diluted wines and Class using Scatter Plot
sns.scatterplot(x='diluted wines', y='Class', data=df_new)
plt.title('diluted wines vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine falls within range of 2.5 to 3.6 diluted wines.
#     -Most of the Class 2 wine falls within range of 2.0 to 3.7 diluted wines.
#     -Most of the Class 3 wine falls within range of 1.2 to 2.3 diluted wines.

# %%
#Checking relationship between Proline and Class using Scatter Plot
df_new.rename(columns={'Proline    ':'Proline'},inplace=True)
df_new.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline'],
#       dtype='object')

# %%
sns.scatterplot(x='Proline',y='Class',data=df_new)
plt.title('Proline vs Class')
plt.show()

# %% [raw]
# Remarks:
#     -Most of the Class 1 wine is present with Proline 760 to 1280.
#     -Most of the Class 2 wine is present with Proline 90 to 780.
#     -Most of the Class 3 wine is present with Proline 490 to 800.

# %% [markdown]
# # Multi-Variate Analysis

# %%
#Checking correlation of features using heatmap
df_corr = df_new.corr()
plt.figure(figsize=(12,10))
sns.heatmap(df_corr,annot=True,fmt='.2f')
plt.title('Correlation of Features')
plt.show()

# %% [raw]
# Remarks:
#     -Flavanoids, diluted wines, Total phenols, Proline, and Hue are negatively high correlated to Class.
#     -Proanthocyanins, Alcohol and Magnesium are negatively moderate correlated to Class.
#     -Alcalinity of ash, Nonfalvanoid phenols and Malic acid are positively high correlated to Class.
#     -Color intensity is positively moderate correlated to Class.
#     -Ash is weakly correlated to Class.

# %%
#Checking correlation of features using bar plot
df_corr['Class'].sort_values(ascending=False).drop(['Class']).plot.bar()
plt.title('Correlation of Features')
plt.ylabel('Correlation Value')
plt.show()

# %% [raw]
# Remarks:
#     -Alcalinity of ash, Nonflavanoid phenols, Malic acid are positively high correlated.
#     -Flavanoids, diluted wines, Total phenols, Proline, Hue, Proanthocyanins are negatively high correlated.

# %% [markdown]
# # Removing Outliers

# %%
#Removing outliers with the help of zscore
from scipy.stats import zscore
import numpy as np

z = np.abs(zscore(df_new))
np.where(z>3) #Printing outlier locations
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121, 123, 158], dtype=int64),
#  array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
df_new_wo = df_new[(z<3).all(axis=1)]
print(f'Original Shape: {df_new.shape}')
print(f'New Shape: {df_new_wo.shape}')
print(f'% Loss: {(len(df_new)-len(df_new_wo))*100/len(df_new)}')
# Out:
# Original Shape: (178, 14)
# New Shape: (168, 14)
# % Loss: 5.617977528089888

# %% [raw]
# Remarks:
#     -Since loss of data is >5, proceeding with original dataset and discarding dataset without outliers

# %% [markdown]
# # Skewness

# %%
#Checking skewness in data
df_new.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %% [raw]
# Remarks:
#     -Malic acid, Magnesium, Color intensity and Proline shows the presence of skewness.

# %% [markdown]
# # Preparing Data for Model

# %%
#Separting Input and Target Variable
x = df_new.drop(columns=['Class'])
y = df_new['Class']
print(x.shape)
print(y.shape)
# Out:
# (178, 13)
# (178,)

# %%
#Handling skewness of data
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
#Scaling data using StandardScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_x = sc.fit_transform(x)

# %%
#Finding best random_state for train test split using GaussianNB Classification
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
best_aScore = 0
best_rState = 0
for i in range(1000):
    x_train, x_test, y_train, y_test = train_test_split(scaled_x,y,test_size=0.25,random_state=i)
    Gnb = GaussianNB()
    Gnb.fit(x_train,y_train)
    predict_y = Gnb.predict(x_test)
    temp_aScore = accuracy_score(y_test,predict_y)
    if temp_aScore>best_aScore:
        best_aScore = temp_aScore
        best_rState = i
        
print(f'Best random_state: {best_rState} with best cross_val_score: {best_aScore}')
# Out:
# Best random_state: 0 with best cross_val_score: 1.0

# %% [markdown]
# # Spliting train test data with best random_state

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_x,y,test_size=0.25,random_state=0)

# %% [markdown]
# # Finding Best Model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # 1. GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
Gnb = GaussianNB()
Gnb.fit(x_train,y_train)

Gnb_predict_y = Gnb.predict(x_test)

Gnb_aScore = accuracy_score(y_test,Gnb_predict_y)
Gnb_cMatrix = confusion_matrix(y_test,Gnb_predict_y)
Gnb_cReport = classification_report(y_test,Gnb_predict_y)

print(f"Accuracy Score: {Gnb_aScore}")
print(f"Confusion Matrix:\n{Gnb_cMatrix}")
print(f"Classification Report:\n{Gnb_cReport}")
# Out:
# Accuracy Score: 1.0
# Confusion Matrix:
# [[16  0  0]
#  [ 0 21  0]
#  [ 0  0  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00         8
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # 2. SVC

# %%
from sklearn.svm import SVC
Svc = SVC()
Svc.fit(x_train, y_train)

Svc_predict_y = Svc.predict(x_test)

Svc_aScore = accuracy_score(y_test,Svc_predict_y)
Svc_cMatrix = confusion_matrix(y_test,Svc_predict_y)
Svc_cReport = classification_report(y_test,Svc_predict_y)

print(f"Accuracy Score: {Svc_aScore}")
print(f"Confusion Matrix:\n{Svc_cMatrix}")
print(f"Classification Report:\n{Svc_cReport}")
# Out:
# Accuracy Score: 1.0
# Confusion Matrix:
# [[16  0  0]
#  [ 0 21  0]
#  [ 0  0  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00         8
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # 3. DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
Dtc = DecisionTreeClassifier()
Dtc.fit(x_train,y_train)

Dtc_predict_y = Dtc.predict(x_test)

Dtc_aScore = accuracy_score(y_test,Dtc_predict_y)
Dtc_cMatrix = confusion_matrix(y_test,Dtc_predict_y)
Dtc_cReport = classification_report(y_test,Dtc_predict_y)

print(f"Accuracy Score: {Dtc_aScore}")
print(f"Confusion Matrix:\n{Dtc_cMatrix}")
print(f"Classification Report:\n{Dtc_cReport}")
# Out:
# Accuracy Score: 0.9555555555555556
# Confusion Matrix:
# [[15  1  0]
#  [ 0 20  1]
#  [ 0  0  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      0.94      0.97        16
#            2       0.95      0.95      0.95        21
#            3       0.89      1.00      0.94         8
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# # 4. RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
Rfc = RandomForestClassifier()
Rfc.fit(x_train,y_train)

Rfc_predict_y = Rfc.predict(x_test)

Rfc_aScore = accuracy_score(y_test,Rfc_predict_y)
Rfc_cMatrix = confusion_matrix(y_test,Rfc_predict_y)
Rfc_cReport = classification_report(y_test,Rfc_predict_y)

print(f"Accuracy Score: {Rfc_aScore}")
print(f"Confusion Matrix:\n{Rfc_cMatrix}")
print(f"Classification Report:\n{Rfc_cReport}")
# Out:
# Accuracy Score: 0.9777777777777777
# Confusion Matrix:
# [[16  0  0]
#  [ 0 20  1]
#  [ 0  0  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      0.95      0.98        21
#            3       0.89      1.00      0.94         8
#
#     accuracy                           0.98        45
#    macro avg       0.96      0.98      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# # From above models GaussianNB and SVC performs well with accuracy_score 100%. So, proceeding with GaussianNB

# %% [markdown]
# # Saving the model or Serialization

# %%
import joblib
filename = "wine_project_model.pkl"
joblib.dump(Gnb,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
cnc = {"Original":np.array(y_test),"Predicted":np.array(Gnb_predict_y)}
cnc_df = pd.DataFrame(cnc)
cnc_df
# Out:
#     Original  Predicted
# 0          1          1
# 1          3          3
# 2          2          2
# 3          1          1
# 4          2          2
# 5          2          2
# 6          1          1
# 7          3          3
# 8          2          2
# 9          2          2
# 10         3          3
# 11         3          3
# 12         1          1
# 13         2          2
# 14         3          3
# 15         2          2
# 16         1          1
# 17         1          1
# 18         2          2
# 19         1          1
# 20         2          2
# 21         1          1
# 22         1          1
# 23         2          2
# 24         2          2
# 25         2          2
# 26         2          2
# 27         2          2
# 28         2          2
# 29         3          3
# 30         1          1
# 31         1          1
# 32         2          2
# 33         1          1
# 34         1          1
# 35         1          1
# 36         3          3
# ...

# %% [raw]
# Remarks:
#     -Comparision table shows that predicted w.r.t. original is with 100% accuracy.
